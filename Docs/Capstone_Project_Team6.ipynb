# %% [markdown]
# **Mile Stone 1- Data Loading and Exploration**

# %%
# importing the packages
import os
for dirname, _, filenames in os.walk('/content/sample_data/creditcard_DataSet.csv'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#load the dataset(Milestone1)
import pandas as pd
data = pd.read_csv("/content/sample_data/creditcard_DataSet.csv")

# %%
# Data Exploration(Milestone1)
print(data.columns)
data.head()
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# ...

# %%
# Checking the data Shape
print(data.shape)
print(data.describe())

# Note: here,V1 - V28 are results of a PCA Dimensionality reduction to protect user identities and other sensitive info
# Out:
# (7973, 31)
#                Time           V1           V2           V3           V4  \
# count   7973.000000  7973.000000  7973.000000  7973.000000  7973.000000
# mean    4257.151261    -0.299740     0.295226     0.899355     0.215736
# std     3198.964299     1.498341     1.283914     1.090297     1.447057
# min        0.000000   -23.066842   -25.640527   -12.389545    -4.657545
# 25%     1531.000000    -1.046362    -0.237359     0.372435    -0.687521
# 50%     3635.000000    -0.416341     0.335446     0.948695     0.223379
# 75%     6662.000000     1.122758     0.950582     1.597949     1.131542
# max    10981.000000     1.685314     8.261750     4.101716     7.380245
#
#                 V5           V6           V7           V8           V9  ...  \
# count  7973.000000  7973.000000  7973.000000  7973.000000  7973.000000  ...
# mean     -0.025285     0.157286    -0.026445    -0.070525     0.655244  ...
# std       1.167218     1.325015     1.063709     1.332568     1.156618  ...
# ...

# %% [markdown]
# **Milestone 2- Data Analysis and Visualization**

# %%
# Milestone2- distribution of value "amount"
import seaborn as sns
import matplotlib.pyplot as plt
amount = [data['Amount'].values]
sns.distplot(amount)
# Out:
# <ipython-input-6-e786c737737a>:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(amount)
# <Axes: ylabel='Density'>

# %%
# finding distribution of time
time = data['Time'].values
sns.distplot(time)
# Out:
# <ipython-input-7-31813f779f9e>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(time)
# <Axes: ylabel='Density'>

# %%
#mile stone 2
from matplotlib import gridspec
features = data.iloc[:,0:28].columns

plt.figure(figsize=(12,28*4))
gs = gridspec.GridSpec(28, 1)
for i, c in enumerate(data[features]):
    ax = plt.subplot(gs[i])
    sns.distplot(data[c][data.Class == 1], bins=50)
    sns.distplot(data[c][data.Class == 0], bins=50)
    ax.set_xlabel('')
    ax.set_title('histogram of feature: ' + str(c))
plt.show()
# Out:
# <ipython-input-8-3dc43bca0e7a>:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data[c][data.Class == 1], bins=50)
# <ipython-input-8-3dc43bca0e7a>:10: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data[c][data.Class == 0], bins=50)
# ...

# %%
#plotting histograms for each individual parameter
data.hist(figsize = (20, 20))
plt.show()

# %%
#checking for fraudlent transactions in the dataset
Fraud = data[data['Class'] == 1]
Valid = data[data['Class'] == 0]

outlier_fraction = len(Fraud)/float(len(Valid))
print(outlier_fraction)

print('Fraud Cases: {}'.format(len(data[data['Class'] == 1])))
print('Valid Transactions: {}'.format(len(data[data['Class'] == 0])))
# Out:
# 0.0031458411979363283
# Fraud Cases: 25
# Valid Transactions: 7947

# %%
print("Details of Amount of Fraudlent Transactions")
Fraud.Amount.describe()
# Out:
# Details of Amount of Fraudlent Transactions
# count      25.000000
# mean      106.308400
# std       372.676883
# min         0.000000
# 25%         1.000000
# 50%         1.000000
# 75%         1.000000
# max      1809.680000
# Name: Amount, dtype: float64

# %%
print("Amount details of valid transactions")
Valid.Amount.describe()
# Out:
# Amount details of valid transactions
# count    7947.000000
# mean       65.284891
# std       194.126547
# min         0.000000
# 25%         4.795000
# 50%        15.950000
# 75%        54.990000
# max      7712.430000
# Name: Amount, dtype: float64

# %%
# Building a Correlation matrix
corrmat = data.corr()
fig = plt.figure(figsize = (12, 9))

sns.heatmap(corrmat, vmax = .9, square = True)
plt.show()

# %% [markdown]
# **Milestone 3- splitting data into training and testing**

# %%
#Milestone 3
#seperating the x, y values.
X=data.drop(['Class'], axis=1)
Y=data["Class"]
print(X.shape)
print(Y.shape)
#generating values of x,y
X_data=X.values
Y_data=Y.values
# Out:
# (7973, 30)
# (7973,)

# %%
X_data
# Out:
# array([[ 0.00000000e+00, -1.35980713e+00, -7.27811733e-02, ...,
#          1.33558377e-01, -2.10530535e-02,  1.49620000e+02],
#        [ 0.00000000e+00,  1.19185711e+00,  2.66150712e-01, ...,
#         -8.98309914e-03,  1.47241692e-02,  2.69000000e+00],
#        [ 1.00000000e+00, -1.35835406e+00, -1.34016307e+00, ...,
#         -5.53527940e-02, -5.97518406e-02,  3.78660000e+02],
#        ...,
#        [ 1.09810000e+04, -7.25174766e-01,  2.98202350e-01, ...,
#         -3.11419393e-02,  2.55638666e-02,  1.29500000e+01],
#        [ 1.09810000e+04,  1.22615304e+00, -1.29645121e-01, ...,
#         -1.00081361e-01, -9.86920840e-03,  1.59500000e+01],
#        [ 1.09810000e+04,  1.14538094e+00, -5.93493602e-02, ...,
#                     nan,             nan,             nan]])

# %% [markdown]
# Using scikit learn for splitting the data into training and testing data

# %%
from sklearn.model_selection import train_test_split
# splitting
X_train, X_test, Y_train, Y_test = train_test_split(X_data, Y_data, test_size = 0.2, random_state = 42)

# %%
from sklearn.metrics import classification_report, accuracy_score,precision_score,recall_score,f1_score,matthews_corrcoef
from sklearn.metrics import confusion_matrix

# %% [markdown]
# **Building a Random Forest Classifier for further analysis and Classification**

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.impute import SimpleImputer
from sklearn.metrics import classification_report, accuracy_score, precision_score, recall_score, f1_score, matthews_corrcoef
from sklearn.metrics import confusion_matrix
# Assuming X_train, Y_train, X_test, and Y_test are defined earlier in the code
X_imputer = SimpleImputer(strategy="mean")
Y_imputer = SimpleImputer(strategy="mean")

X_train = X_imputer.fit_transform(X_train)
Y_train = Y_imputer.fit_transform(Y_train.reshape(-1, 1)).ravel()

# Apply the imputer on the test data
X_test = X_imputer.transform(X_test)
Y_test = Y_imputer.transform(Y_test.reshape(-1, 1)).ravel()



rfc = RandomForestClassifier()
rfc.fit(X_train, Y_train)

# Making the predictions
y_pred = rfc.predict(X_test)

# Evaluating the classifier
n_outliers = len(Fraud)
n_errors = (y_pred != Y_test).sum()
print("The model used is Random Forest classifier")
acc = accuracy_score(Y_test, y_pred)
print("The accuracy is  {}".format(acc))
prec = precision_score(Y_test, y_pred)
print("The precision is {}".format(prec))
rec = recall_score(Y_test, y_pred)
print("The recall is {}".format(rec))
f1 = f1_score(Y_test, y_pred)
print("The F1-Score is {}".format(f1))
MCC = matthews_corrcoef(Y_test, y_pred)
print("The Matthews correlation coefficient is {}".format(MCC))
# Out:
# The model used is Random Forest classifier
# The accuracy is  1.0
# The precision is 1.0
# The recall is 1.0
# The F1-Score is 1.0
# The Matthews correlation coefficient is 1.0
